# %%
from graphviz import Digraph

d = Digraph()

d.edge('1', '1', '1/3')
d.edge('1', '3', '1/3')
d.edge('1', '6', '1/3')

d.edge('2', '1', '1/2')
d.edge('2', '2', '1/4')
d.edge('2', '3', '1/4')

d.edge('3', '5', '1')

d.edge('4', '1', '1/4')
d.edge('4', '2', '1/4')
d.edge('4', '3', '1/4')
d.edge('4', '6', '1/4')

d.edge('5', '3', '1')

d.edge('6', '6', '1')

d

# %%
# %reset -f
