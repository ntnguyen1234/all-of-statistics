# %%
from graphviz import Digraph

d = Digraph()

d.edge('1', '1', 'q')
d.edge('1', '2', 'p')

d.edge('2', '1', 'q')
d.edge('2', '3', 'p')

d.edge('3', '1', 'q')
d.edge('3', '4', 'p')

d.edge('4', '1', 'q')
d.edge('4', '5', 'p')

d.edge('5', '1', '1')

d

# %%
# %reset -f
