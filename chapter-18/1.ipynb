# %%
from graphviz import Graph

G = Graph(graph_attr={'rankdir': 'LR'})

G.edge('X1', 'X2')
G.edge('X2', 'X3')
G

# %%
G = Graph()

G.node('X1')
G.edge('X2', 'X3')
G

# %%
G = Graph()

G.node('X1')
G.node('X2')
G.node('X3')
G

# %%
# %reset -f
