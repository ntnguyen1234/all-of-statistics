# %%
from graphviz import Graph

G = Graph(graph_attr={'rankdir': 'LR'})

G.edge('X1', 'X2')
G.edge('X2', 'X3')
G.edge('X3', 'X4')
G

# %%
G = Graph()

G.edge('X1', 'X4')
G.edge('X2', 'X4')
G.edge('X3', 'X4')
G

# %%
G = Graph(graph_attr={'rankdir': 'LR'})

G.edge('X1', 'X2')
G.edge('X2', 'X3')
G.edge('X3', 'X4')
G.edge('X4', 'X1')
G

# %%
# %reset -f
